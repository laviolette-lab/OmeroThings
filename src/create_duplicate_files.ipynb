# %%
# THIS HAS TO ACTUALLY BE RUN IN THE TERMINAL, NOT IN PYTHON
omero login -s wss://wsi.lavlab.mcw.edu/omero-wss
while read ID; do omero duplicate "Image:$ID" --ignore Roi --report; done < omero_ids.txt
# Out:
#   Cell In[1], line 2
#     omero -s wss://wsi.lavlab.mcw.edu/omero-wss -u sduenweg -w 'Jasper100308#' duplicate Image:454 --ignore Roi --report
#              ^
# SyntaxError: invalid syntax

# %%
from omero.gateway import BlitzGateway
conn = BlitzGateway("savannahduenweg", "Jasper100308#", host="wss://wsi.lavlab.mcw.edu/omero-wss", port=443, secure=True)
conn.connect()
conn.c.enableKeepAlive(60000000)
